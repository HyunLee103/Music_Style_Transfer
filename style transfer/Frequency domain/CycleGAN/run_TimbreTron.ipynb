# %%
# !python3 '/content/drive/My Drive/ADV_Project_Music_style_transform/timbreTron_cycleGAN/train.py' \
--n_epochs 200 \
--dataroot '/content/drive/My Drive/ADV_Project_Music_style_transform/timbreTron_cycleGAN/cqt_sample/other' \
--input_nc 1 \
--batchSize 10 \
--decay_epoch 150 \
--output_nc 1 \

# %%
# !pip install visdom
output.clear()

# %% [markdown]
# # Implement
#
# generator : Unet 씀, 인코더 layer 6개, 디코더 layer 6 개
